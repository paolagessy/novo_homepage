# %%
import numpy as np
import pandas as pd 
from scipy.integrate import simps
from scipy.integrate import trapezoid
#from prettytable import PrettyTable
from prettytable import from_csv
from prettytable import from_html

import matplotlib.pyplot as plt
from lightkurve import search_lightcurve 
import lightkurve as lk
# Out:
# /home/paola/anaconda3/lib/python3.9/site-packages/lightkurve/config/__init__.py:119: UserWarning: The default Lightkurve cache directory, used by download(), etc., has been moved to /home/paola/.lightkurve/cache. Please move all the files in the legacy directory /home/paola/.lightkurve-cache to the new location and remove the legacy directory. Refer to https://docs.lightkurve.org/reference/config.html#default-cache-directory-migration for more information.
#   warnings.warn(

# %%
#### Parametros do setor 1 ######
data=np.loadtxt('parametros_setor1.txt')
data5=np.loadtxt('par_s1.txt')
dur=data[:,0]
sub=data[:,1]
des=data[:,2]
ampl=data[:,3]
ener0 = data[:,4]
ener = data5
print(np.mean(ampl))
# Out:
# 0.009552066666666666

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colors
from matplotlib.ticker import PercentFormatter

n_bins = 10

# Creating distribution
x = np.log10(ener)
y = len(ener)
plt.rcParams['font.size'] = '21'
# Creating histogram
fig, axs = plt.subplots(1, 1,
                        figsize =(10, 7),
                        tight_layout = True)
 
axs.hist(x, bins = n_bins, color='purple', label = "d")
#labels= ["Energia"]
plt.ylabel("Quantidade de explosões").set_fontsize(21)
plt.xlabel("Log10(Energia)[ergs]").set_fontsize(21)
plt.ylim(0,8)
plt.xlim(31.5,34.5)
plt.title('Setor 1 (2 min)').set_fontsize(21)
#plt.legend(labels)
plt.xticks(fontsize = 21)
plt.yticks(fontsize = 21)
# Show plot
plt.show()
plt.savefig('nome_do_arquivo.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_245070/290407370.py in <cell line: 24>()
#      22 plt.xlim(31.5,34.5)
#      23 plt.title('Setor 1 (2 min)').set_fontsize(21)
# ---> 24 plt.legend(labels)
#      25 plt.xticks(fontsize = 21)
#      26 plt.yticks(fontsize = 21)
#
# NameError: name 'labels' is not defined

# %%
n_bins = 10

# Creating distribution
x = dur
y = len(dur)
plt.rcParams['font.size'] = '21'
# Creating histogram
fig, axs = plt.subplots(1, 1,
                        figsize =(10, 7),
                        tight_layout = True)
 

axs.hist(x, bins = n_bins, color='gray', label = "d")
#labels= ["Duração"]
plt.ylabel("Quantidade de explosões").set_fontsize(21)
plt.xlabel("t(min)").set_fontsize(21)
plt.ylim(0,30)
plt.xlim(0,400)
plt.title('Setor 1 (2 min)').set_fontsize(21)
plt.legend(labels)
plt.xticks(fontsize = 21)
plt.yticks(fontsize = 21)
# Save the plot before showing
plt.savefig('his_dur_1.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_245070/3330321900.py in <cell line: 20>()
#      18 plt.xlim(0,400)
#      19 plt.title('Setor 1 (2 min)').set_fontsize(21)
# ---> 20 plt.legend(labels)
#      21 plt.xticks(fontsize = 21)
#      22 plt.yticks(fontsize = 21)
#
# NameError: name 'labels' is not defined

# %%
n_bins = 10

# Creating distribution
x = sub
y = len(sub)
plt.rcParams['font.size'] = '21' 
# Creating histogram
fig, axs = plt.subplots(1, 1,
                        figsize =(10, 7),
                        tight_layout = True)
 
axs.hist(x, bins = n_bins)
#labels= ["Tempo de subida"]
plt.ylabel("Quantidade de explosões").set_fontsize(21)
plt.xlabel("t(min)").set_fontsize(21)
plt.title('Setor 1 (2 min)').set_fontsize(21)
plt.ylim(0,30)
plt.xlim(0,210)
#plt.legend(labels)
plt.xticks(fontsize = 21)
plt.yticks(fontsize = 21)
plt.savefig('his_sub_1.png')

# %%
n_bins = 10

# Creating distribution
x = des
y = len(des)
plt.rcParams['font.size'] = '21'  
# Creating histogram
fig, axs = plt.subplots(1, 1,
                        figsize =(10, 7),
                        tight_layout = True)
 
axs.hist(x, bins = n_bins, color='y')
#labels= ["Tempo de descida"]
plt.ylabel("Quantidade de explosões").set_fontsize(21)
plt.xlabel("t(min)").set_fontsize(21)
plt.title('Setor 1 (2 min)').set_fontsize(21)
plt.ylim(0,30)
plt.xlim(0,300)
#plt.legend(labels)
plt.xticks(fontsize = 21)
plt.yticks(fontsize = 21)
plt.savefig('his_des_1.png')

# %%
n_bins = 10

# Creating distribution
x = ampl
y = len(ampl)
plt.rcParams['font.size'] = '21' 
# Creating histogram
fig, axs = plt.subplots(1, 1,
                        figsize =(10, 7),
                        tight_layout = True)
 
axs.hist(x, bins = n_bins, color='red', label = "d")
#labels= ["Amplitude"]
plt.ylabel("Quantidade de explosões").set_fontsize(21)
plt.xlabel("Amplitudes").set_fontsize(21)
plt.ylim(0,25)
plt.xlim(0,0.045)
plt.title('Setor 1 (2 min)').set_fontsize(21)
#plt.legend(labels)
plt.xticks(fontsize = 21)
plt.yticks(fontsize = 21) 
plt.savefig('his_ampl_1')

# %%
import numpy as np
from scipy.stats import linregress
import matplotlib.pyplot as plt

# Exemplo de dados de entrada e saída
X = np.log10(ener)
y = np.log10(dur)
# Use linregress para ajustar o modelo linear
slope, intercept, r_value, p_value, std_err = linregress(X, y)

# Faça previsões para os valores existentes de X
predictions = slope *X + intercept

# Plote os dados originais e a linha de regressão
plt.scatter(X, y, label='Dados', color='black', marker="*")
plt.plot(X, predictions, label='Regressão Linear', color='red')
plt.ylabel('Log10(Duração)[Min]')
plt.xlabel('Log10(Energia)[Ergs]')
plt.legend()
plt.title('Setor 1 (2 min)')
plt.show()

# Imprima os coeficientes e outras estatísticas
print(f"Coeficiente Angular (Slope): {slope}")
print(f"Coeficiente Linear (Intercept): {intercept}")
print(f"Coeficiente de Correlação (r): {r_value}")
print(f"Valor-p (p-value): {p_value}")
print(f"Erro Padrão (Standard Error): {std_err}")
# Out:
# Coeficiente Angular (Slope): 0.537114671999243
# Coeficiente Linear (Intercept): -15.87712120822265
# Coeficiente de Correlação (r): 0.9066756754110246
# Valor-p (p-value): 3.7300119068116433e-13
# Erro Padrão (Standard Error): 0.04488177717262043
